# %%
# khởi tạo
nhà = ["hành lamg", 11.25,"nhà bếp", 18.0, "phòng khách ", 20.0, "phòng ngủ", 10.75, "phòng t`ắm", 9.50]
nhà[-1] = 10.50
nhà[4] = 'khu vui chơi'
print(nhà)
# Out:
# ['hành lamg', 11.25, 'nhà bếp', 18.0, 'khu vui chơi', 20.0, 'phòng ngủ', 10.75, 'phòng tắm', 10.5]

# %%
nhà = ["hành lamg", 11.25, "nhà bếp", 18.0, "phòng khách ", 20.0, "phòng ngủ", 10.75, "phòng tắm", 9.50]
nhà_1 = nhà + ["bể bơi",24.5]
nhà_2 = nhà_1 + ["gara ô tô",15.45]
print (nhà_1)
print (nhà_2)
# Out:
# ['hành lamg', 11.25, 'nhà bếp', 18.0, 'phòng khách ', 20.0, 'phòng ngủ', 10.75, 'phòng tắm', 9.5, 'bể bơi', 24.5]
# ['hành lamg', 11.25, 'nhà bếp', 18.0, 'phòng khách ', 20.0, 'phòng ngủ', 10.75, 'phòng tắm', 9.5, 'bể bơi', 24.5, 'gara ô tô', 15.45]

# %%
print (nhà_2)
# Out:
# ['hành lamg', 11.25, 'nhà bếp', 18.0, 'phòng khách ', 20.0, 'phòng ngủ', 10.75, 'phòng tắm', 9.5, 'bể bơi', 24.5, 'gara ô tô', 15.45]

# %%
del (nhà_2[11])
print (nhà_2)
# Out:
# ['hành lamg', 11.25, 'nhà bếp', 18.0, 'phòng khách ', 20.0, 'phòng ngủ', 10.75, 'phòng tắm', 9.5, 'bể bơi', 'gara ô tô', 15.45]

# %%
del (nhà_2[-3])
print (nhà_2)
# Out:
# ['hành lamg', 11.25, 'nhà bếp', 18.0, 'phòng khách ', 20.0, 'phòng ngủ', 10.75, 'phòng tắm', 9.5, 'gara ô tô', 15.45]

# %%
nhà_2[0]
# Out:
# 'hành lamg'

# %%
nhà_2
# Out:
# ['hành lamg',
#  11.25,
#  'nhà bếp',
#  18.0,
#  'phòng khách ',
#  20.0,
#  'phòng ngủ',
#  10.75,
#  'phòng tắm',
#  9.5,
#  'gara ô tô',
#  15.45]

# %%
print (nhà_2)
# Out:
# ['hành lamg', 11.25, 'nhà bếp', 18.0, 'phòng khách ', 20.0, 'phòng ngủ', 10.75, 'phòng tắm', 9.5, 'gara ô tô', 15.45]
